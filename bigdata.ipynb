# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/GlobalTemperatures (1).csv')
df.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 9 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   dt                                         3192 non-null   object
#  1   LandAverageTemperature                     3180 non-null   float64
#  2   LandAverageTemperatureUncertainty          3180 non-null   float64
#  3   LandMaxTemperature                         1992 non-null   float64
#  4   LandMaxTemperatureUncertainty              1992 non-null   float64
#  5   LandMinTemperature                         1992 non-null   float64
#  6   LandMinTemperatureUncertainty              1992 non-null   float64
#  7   LandAndOceanAverageTemperature             1992 non-null   float64
#  8   LandAndOceanAverageTemperatureUncertainty  1992 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 224.6+ KB

# %%
df.isnull().sum()
# Out:
# dt                                              0
# LandAverageTemperature                         12
# LandAverageTemperatureUncertainty              12
# LandMaxTemperature                           1200
# LandMaxTemperatureUncertainty                1200
# LandMinTemperature                           1200
# LandMinTemperatureUncertainty                1200
# LandAndOceanAverageTemperature               1200
# LandAndOceanAverageTemperatureUncertainty    1200
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# dt                                           0
# LandAverageTemperature                       0
# LandAverageTemperatureUncertainty            0
# LandMaxTemperature                           0
# LandMaxTemperatureUncertainty                0
# LandMinTemperature                           0
# LandMinTemperatureUncertainty                0
# LandAndOceanAverageTemperature               0
# LandAndOceanAverageTemperatureUncertainty    0
# dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-7-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                            LandAverageTemperature  \
# LandAverageTemperature                                   1.000000
# LandAverageTemperatureUncertainty                       -0.143129
# LandMaxTemperature                                       0.995807
# LandMaxTemperatureUncertainty                           -0.108462
# LandMinTemperature                                       0.995611
# LandMinTemperatureUncertainty                           -0.167451
# LandAndOceanAverageTemperature                           0.988066
# LandAndOceanAverageTemperatureUncertainty               -0.131412
#
#                                            LandAverageTemperatureUncertainty  \
# LandAverageTemperature                                             -0.143129
# LandAverageTemperatureUncertainty                                   1.000000
# LandMaxTemperature                                                 -0.132905
# LandMaxTemperatureUncertainty                                       0.866944
# LandMinTemperature                                                 -0.165066
# LandMinTemperatureUncertainty                                       0.888717
# LandAndOceanAverageTemperature                                     -0.208008
# LandAndOceanAverageTemperatureUncertainty                           0.972405
#
#                                            LandMaxTemperature  \
# LandAverageTemperature                               0.995807
# LandAverageTemperatureUncertainty                   -0.132905
# LandMaxTemperature                                   1.000000
# LandMaxTemperatureUncertainty                       -0.105349
# LandMinTemperature                                   0.993404
# LandMinTemperatureUncertainty                       -0.160020
# LandAndOceanAverageTemperature                       0.983855
# LandAndOceanAverageTemperatureUncertainty           -0.120563
#
#                                            LandMaxTemperatureUncertainty  \
# LandAverageTemperature                                         -0.108462
# LandAverageTemperatureUncertainty                               0.866944
# LandMaxTemperature                                             -0.105349
# LandMaxTemperatureUncertainty                                   1.000000
# LandMinTemperature                                             -0.123251
# LandMinTemperatureUncertainty                                   0.868702
# LandAndOceanAverageTemperature                                 -0.163396
# LandAndOceanAverageTemperatureUncertainty                       0.860425
#
#                                            LandMinTemperature  \
# LandAverageTemperature                               0.995611
# LandAverageTemperatureUncertainty                   -0.165066
# LandMaxTemperature                                   0.993404
# LandMaxTemperatureUncertainty                       -0.123251
# LandMinTemperature                                   1.000000
# LandMinTemperatureUncertainty                       -0.185512
# LandAndOceanAverageTemperature                       0.986402
# LandAndOceanAverageTemperatureUncertainty           -0.154931
#
#                                            LandMinTemperatureUncertainty  \
# LandAverageTemperature                                         -0.167451
# LandAverageTemperatureUncertainty                               0.888717
# LandMaxTemperature                                             -0.160020
# LandMaxTemperatureUncertainty                                   0.868702
# LandMinTemperature                                             -0.185512
# LandMinTemperatureUncertainty                                   1.000000
# LandAndOceanAverageTemperature                                 -0.221746
# LandAndOceanAverageTemperatureUncertainty                       0.880062
#
#                                            LandAndOceanAverageTemperature  \
# LandAverageTemperature                                           0.988066
# LandAverageTemperatureUncertainty                               -0.208008
# LandMaxTemperature                                               0.983855
# LandMaxTemperatureUncertainty                                   -0.163396
# LandMinTemperature                                               0.986402
# LandMinTemperatureUncertainty                                   -0.221746
# LandAndOceanAverageTemperature                                   1.000000
# LandAndOceanAverageTemperatureUncertainty                       -0.203072
#
#                                            LandAndOceanAverageTemperatureUncertainty
# LandAverageTemperature                                                     -0.131412
# LandAverageTemperatureUncertainty                                           0.972405
# LandMaxTemperature                                                         -0.120563
# LandMaxTemperatureUncertainty                                               0.860425
# LandMinTemperature                                                         -0.154931
# LandMinTemperatureUncertainty                                               0.880062
# LandAndOceanAverageTemperature                                             -0.203072
# LandAndOceanAverageTemperatureUncertainty                                   1.000000

# %%
x=df.drop('dt',axis='columns')
y=df['LandAverageTemperature']
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
'''from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(X_train)
x_test=scaler.fit_transform(X_test)

# %%
import statsmodels.api as sm

model = sm.OLS(y_train,X_train).fit()

# %%
y_pred=model.predict(X_test)
data=list(zip(y_test,y_pred))

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
print('MAE:', mae)
print('MSE:', mse)
print('RMSE:', rmse)
print('R²:', r2)
# Out:
# MAE: 2.130292600634135e-15
# MSE: 6.678626911871123e-30
# RMSE: 2.5843039511387052e-15
# R²: 1.0
